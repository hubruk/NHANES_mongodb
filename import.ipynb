# %%
import pymongo
import pandas as pd
import json
import csv

# %%
client = pymongo.MongoClient("mongodb+srv://hubruk:m3kowmmkeE@cluster0.2lppi7r.mongodb.net/myFirstDatabase")

# %% [markdown]
# #

# %%
demographic = pd.read_csv("national_health\demographic.csv")

# %%
demographic_dict = demographic.to_dict(orient="records")

# %%
demographic.nunique()
# Out:
# SEQN        10175
# SDDSRVYR        1
# RIDSTATR        2
# RIAGENDR        2
# RIDAGEYR       81
# RIDAGEMN       25
# RIDRETH1        5
# RIDRETH3        6
# RIDEXMON        2
# RIDEXAGM      240
# DMQMILIZ        3
# DMQADFC         3
# DMDBORN4        4
# DMDCITZN        4
# DMDYRSUS       11
# DMDEDUC3       19
# DMDEDUC2        7
# DMDMARTL        8
# RIDEXPRG        3
# SIALANG         2
# SIAPROXY        2
# SIAINTRP        2
# FIALANG         2
# FIAPROXY        2
# FIAINTRP        2
# MIALANG         2
# MIAPROXY        2
# MIAINTRP        2
# AIALANGA        3
# DMDHHSIZ        7
# DMDFMSIZ        7
# DMDHHSZA        4
# DMDHHSZB        5
# DMDHHSZE        4
# DMDHRGND        2
# DMDHRAGE       63
# DMDHRBR4        3
# DMDHREDU        7
# DMDHRMAR        8
# DMDHSEDU        7
# WTINT2YR     7076
# WTMEC2YR     8170
# SDMVPSU         2
# SDMVSTRA       15
# INDHHIN2       16
# INDFMIN2       16
# INDFMPIR      440
# dtype: int64

# %%
demographic_dict
# Out:
# [{'SEQN': 73557,
#   'SDDSRVYR': 8,
#   'RIDSTATR': 2,
#   'RIAGENDR': 1,
#   'RIDAGEYR': 69,
#   'RIDAGEMN': nan,
#   'RIDRETH1': 4,
#   'RIDRETH3': 4,
#   'RIDEXMON': 1.0,
#   'RIDEXAGM': nan,
#   'DMQMILIZ': 1.0,
#   'DMQADFC': 1.0,
#   'DMDBORN4': 1,
#   'DMDCITZN': 1.0,
#   'DMDYRSUS': nan,
#   'DMDEDUC3': nan,
#   'DMDEDUC2': 3.0,
#   'DMDMARTL': 4.0,
#   'RIDEXPRG': nan,
#   'SIALANG': 1,
#   'SIAPROXY': 2.0,
#   'SIAINTRP': 2,
#   'FIALANG': 1.0,
#   'FIAPROXY': 2.0,
#   'FIAINTRP': 2.0,
#   'MIALANG': 1.0,
#   'MIAPROXY': 2.0,
#   'MIAINTRP': 2.0,
#   'AIALANGA': 1.0,
#   'DMDHHSIZ': 3,
#   'DMDFMSIZ': 3,
#   'DMDHHSZA': 0,
#   'DMDHHSZB': 0,
#   'DMDHHSZE': 2,
#   'DMDHRGND': 1,
#   'DMDHRAGE': 69,
#   'DMDHRBR4': 1.0,
#   'DMDHREDU': 3.0,
#   'DMDHRMAR': 4.0,
#   'DMDHSEDU': nan,
#   'WTINT2YR': 13281.237386,
#   'WTMEC2YR': 13481.042095,
#   'SDMVPSU': 1,
#   'SDMVSTRA': 112,
#   'INDHHIN2': 4.0,
#   'INDFMIN2': 4.0,
#   'INDFMPIR': 0.84},
#  {'SEQN': 73558,
# ...

# %%
diet = pd.read_csv("national_health\diet.csv")

# %%
examination = pd.read_csv("national_health\examination.csv")

# %%
labs = pd.read_csv("national_health\labs.csv")

# %%
import chardet    
rawdata = open('national_health\medications.csv', 'rb').read()
result = chardet.detect(rawdata)
charenc = result['encoding']
print(charenc)
# Out:
# ISO-8859-1

# %%
medications = pd.read_csv("national_health\medications.csv", encoding = charenc)

# %%
questionnaire = pd.read_csv("national_health\questionnaire.csv")

# %%
db = client["national_health"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['ac-ltqtr0s-shard-00-00.2lppi7r.mongodb.net:27017', 'ac-ltqtr0s-shard-00-02.2lppi7r.mongodb.net:27017', 'ac-ltqtr0s-shard-00-01.2lppi7r.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-balcde-shard-0', tls=True), 'national_health')

# %%
#db.demographic.insert_many(demographic_dict)
